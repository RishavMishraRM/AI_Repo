# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('height-weight.csv')

# %%
df.head()
# Out:
#    Weight  Height
# 0      45     120
# 1      58     135
# 2      48     123
# 3      60     145
# 4      70     160

# %%
# scatter plot
plt.scatter(df['Height'], df['Weight'])
plt.title('Height vs Weight')
plt.xlabel('Weight')
plt.ylabel('Height')
# Out:
# Text(0, 0.5, 'Height')

# %%
## Correlation
df.corr()
# Out:
#           Weight    Height
# Weight  1.000000  0.931142
# Height  0.931142  1.000000

# %%
# Seaborn for Visualization
import seaborn as sns
sns.pairplot(df)

# %%
## Independent and Dependent Features
### Always make sure that the independent features should be in form of 2D array or in dataframe

df.head(10)
# Out:
#    Weight  Height
# 0      45     120
# 1      58     135
# 2      48     123
# 3      60     145
# 4      70     160
# 5      78     162
# 6      80     163
# 7      90     175
# 8      95     182
# 9      78     170

# %%
# It should be like this
X=df[['Weight']] ### independent features should be data frame or 2 dimesnionalarray
y=df['Height'] ## this variiable can be in series or 1d array
#np.array(X).shape

# %%
# X shouldn't be like this
X_series=df['Weight']
np.array(X_series).shape
# Out:
# (23,)

# %%
np.array(y).shape
# Out:
# (23,)

# %%
## Train Test Split
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.25,random_state=42)

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (17, 1)
# (6, 1)
# (17,)
# (6,)

# %%
## Standardization
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()
X_train=scaler.fit_transform(X_train)

# %%
X_test=scaler.transform(X_test)

# %%
X_test
# Out:
# array([[ 0.33497168],
#        [ 0.33497168],
#        [-1.6641678 ],
#        [ 1.36483141],
#        [-0.45256812],
#        [ 1.97063125]])

# %%
## Apply Simple Linear Regression
from sklearn.linear_model import LinearRegression

# %%
regression=LinearRegression(n_jobs=-1)

# %%
regression.fit(X_train,y_train)
# Out:
# LinearRegression(n_jobs=-1)

# %%
print("Coefficient or slope:",regression.coef_)
print("Intercept:",regression.intercept_)
# Out:
# Coefficient or slope: [17.2982057]
# Intercept: 156.47058823529412

# %%
## plot Training data plot best fit line
plt.scatter(X_train,y_train)
plt.plot(X_train,regression.predict(X_train))

# %% [markdown]
# #### Prediction of test data
#  1. predicted height output= intercept +coef_(Weights)
#  2. y_pred_test =156.470 + 17.29(X_test)

# %%
## Prediction for test data
y_pred=regression.predict(X_test)

# %%
## Performance Metrics
from sklearn.metrics import mean_absolute_error,mean_squared_error

# %%
mse=mean_squared_error(y_test,y_pred)
mae=mean_absolute_error(y_test,y_pred)
rmse=np.sqrt(mse)

# %%
print(mse)
print(mae)
print(rmse)
# Out:
# 114.84069295228699
# 9.66512588679501
# 10.716374991212605

# %% [markdown]
# ## R Square Formula
# R^2 = 1 - SSR/SST <br>
# R^2 = coefficient of determination SSR = sum of squares of residuals SST = ttotal sum of squares

# %%
from sklearn.metrics import r2_score

# %%
score=r2_score(y_test,y_pred)
print(score)
# Out:
# 0.7360826717981276

# %% [markdown]
# #### Adjusted R2 = 1 – [(1-R2)*(n-1)/(n-k-1)]
#
# where:
#
# R2: The R2 of the model n: The number of observations k: The number of predictor variables

# %%
#display adjusted R-squared
1 - (1-score)*(len(y_test)-1)/(len(y_test)-X_test.shape[1]-1)
# Out:
# 0.6701033397476595

# %%
## OLS Linear Regression
import statsmodels.api as sm

# %%
model=sm.OLS(y_train,X_train).fit()

# %%
prediction=model.predict(X_test)
print(prediction)
# Out:
# [  5.79440897   5.79440897 -28.78711691  23.60913442  -7.82861638
#   34.08838469]

# %%
print(model.summary())
# Out:
#                                  OLS Regression Results
# ...
# Dep. Variable:                 Height   R-squared (uncentered):                   0.012
# Model:                            OLS   Adj. R-squared (uncentered):             -0.050
# Method:                 Least Squares   F-statistic:                             0.1953
# Date:                Mon, 24 Mar 2025   Prob (F-statistic):                       0.664
# Time:                        13:04:36   Log-Likelihood:                         -110.03
# No. Observations:                  17   AIC:                                      222.1
# Df Residuals:                      16   BIC:                                      222.9
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
## Prediction For new data
regression.predict(scaler.transform([[72]]))
# Out:
# array([155.97744705])
